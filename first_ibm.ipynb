# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Faiz Khan.
# currently student.
# desired to be a data scientist and AI/ML.**

# %% [markdown]
# *I am interested in data science because it allows me to use data to solve real-world problems and make data-driven decisions. I find it fascinating to uncover insights and patterns in data, and I enjoy using my technical and analytical skills to turn data into actionable information. Additionally, I am passionate about using data to improve decision-making and drive positive impact in various industries and domains.*

# %% [markdown]
# ### now i am calculating the marks of 4 subject of a student and gets its average

# %%
(56+45+33+56)/4
# Out:
# 47.5

# %% [markdown]
# this cell is seprated by horizontal seperator
# ***
# this is bulleted list
# - no1
# - no2
#
# this is numbered list
# 1. no1
# 2. no2
#
# this is image
# https://images.app.goo.gl/niRnkdzzNjTRv1Z57
